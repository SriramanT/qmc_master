# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as la
import numpy.random as rd
import copy
import os
import warnings

cwd = os.getcwd()

# %%
weights = np.loadtxt("test.txt")

M = weights.size

time = np.arange(M)

# %%
plt.scatter(time, np.log(weights), s = 0.5)
plt.xlabel('MC step')
plt.ylabel('configuration weight(log-scale)')
# Out:
# Text(0,0.5,'configuration weight(log-scale)')
